# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', validation_size=0)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
inputs_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='inputs')
targets_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='targets')

### Encoder
conv1 = tf.layers.conv2d(inputs_, 16, (3,3), padding='same', activation=tf.nn.relu)
# Now 28x28x16
maxpool1 = tf.layers.max_pooling2d(conv1, (2,2), (2,2), padding='same')
# Now 14x14x16
conv2 = tf.layers.conv2d(maxpool1, 8, (3,3), padding='same', activation=tf.nn.relu)
# Now 14x14x8
maxpool2 = tf.layers.max_pooling2d(conv2, (2,2), (2,2), padding='same')
# Now 7x7x8
conv3 = tf.layers.conv2d(maxpool2, 8, (3,3), padding='same', activation=tf.nn.relu)
# Now 7x7x8
encoded = tf.layers.max_pooling2d(conv3, (2,2), (2,2), padding='same')
# Now 4x4x8

### Decoder
upsample1 = tf.image.resize_nearest_neighbor(encoded, (7,7))
# Now 7x7x8
conv4 = tf.layers.conv2d(upsample1, 8, (3,3), padding='same', activation=tf.nn.relu)
# Now 7x7x8
upsample2 = tf.image.resize_nearest_neighbor(conv4, (14,14))
# Now 14x14x8
conv5 = tf.layers.conv2d(upsample2, 8, (3,3), padding='same', activation=tf.nn.relu)
# Now 14x14x8
upsample3 = tf.image.resize_nearest_neighbor(conv5, (28,28))
# Now 28x28x8
conv6 = tf.layers.conv2d(upsample3, 16, (3,3), padding='same', activation=tf.nn.relu)
# Now 28x28x16

logits = tf.layers.conv2d(conv6, 1, (3,3), padding='same', activation=None)
#Now 28x28x1

decoded = tf.nn.sigmoid(logits, name='decoded')

loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets_, logits=logits)
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(0.001).minimize(cost)

# %%
epochs = 20
batch_size = 200

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            imgs = batch[0].reshape((-1, 28, 28, 1))
            targets = np.zeros(imgs.shape)
            targets[:-1] = imgs[1:]
            targets[-1] = imgs[0]
            batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: imgs,
                                                         targets_: targets})
            
            print("Epochs: {}/{}".format(e+1, epochs), "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epochs: 1/20 Training loss: 0.6941
# Epochs: 1/20 Training loss: 0.6921
# Epochs: 1/20 Training loss: 0.6901
# Epochs: 1/20 Training loss: 0.6879
# Epochs: 1/20 Training loss: 0.6854
# Epochs: 1/20 Training loss: 0.6824
# Epochs: 1/20 Training loss: 0.6784
# Epochs: 1/20 Training loss: 0.6739
# Epochs: 1/20 Training loss: 0.6684
# Epochs: 1/20 Training loss: 0.6619
# Epochs: 1/20 Training loss: 0.6540
# Epochs: 1/20 Training loss: 0.6453
# Epochs: 1/20 Training loss: 0.6340
# Epochs: 1/20 Training loss: 0.6224
# Epochs: 1/20 Training loss: 0.6066
# Epochs: 1/20 Training loss: 0.5913
# Epochs: 1/20 Training loss: 0.5721
# Epochs: 1/20 Training loss: 0.5529
# Epochs: 1/20 Training loss: 0.5322
# Epochs: 1/20 Training loss: 0.5153
# Epochs: 1/20 Training loss: 0.5000
# Epochs: 1/20 Training loss: 0.5039
# Epochs: 1/20 Training loss: 0.5111
# Epochs: 1/20 Training loss: 0.5139
# Epochs: 1/20 Training loss: 0.5247
# Epochs: 1/20 Training loss: 0.5202
# Epochs: 1/20 Training loss: 0.5094
# Epochs: 1/20 Training loss: 0.4976
# Epochs: 1/20 Training loss: 0.4887
# Epochs: 1/20 Training loss: 0.4798
# Epochs: 1/20 Training loss: 0.4724
# Epochs: 1/20 Training loss: 0.4703
# Epochs: 1/20 Training loss: 0.4697
# Epochs: 1/20 Training loss: 0.4696
# Epochs: 1/20 Training loss: 0.4654
# Epochs: 1/20 Training loss: 0.4636
# Epochs: 1/20 Training loss: 0.4498
# Epochs: 1/20 Training loss: 0.4468
# Epochs: 1/20 Training loss: 0.4484
# Epochs: 1/20 Training loss: 0.4369
# Epochs: 1/20 Training loss: 0.4409
# Epochs: 1/20 Training loss: 0.4245
# Epochs: 1/20 Training loss: 0.4231
# Epochs: 1/20 Training loss: 0.4139
# Epochs: 1/20 Training loss: 0.4135
# Epochs: 1/20 Training loss: 0.4069
# Epochs: 1/20 Training loss: 0.4005
# Epochs: 1/20 Training loss: 0.3930
# Epochs: 1/20 Training loss: 0.3747
# Epochs: 1/20 Training loss: 0.3894
# Epochs: 1/20 Training loss: 0.3705
# Epochs: 1/20 Training loss: 0.3644
# Epochs: 1/20 Training loss: 0.3593
# Epochs: 1/20 Training loss: 0.3490
# Epochs: 1/20 Training loss: 0.3464
# Epochs: 1/20 Training loss: 0.3382
# Epochs: 1/20 Training loss: 0.3274
# Epochs: 1/20 Training loss: 0.3228
# Epochs: 1/20 Training loss: 0.3193
# Epochs: 1/20 Training loss: 0.3139
# Epochs: 1/20 Training loss: 0.3000
# Epochs: 1/20 Training loss: 0.3011
# Epochs: 1/20 Training loss: 0.2965
# Epochs: 1/20 Training loss: 0.2858
# Epochs: 1/20 Training loss: 0.2879
# Epochs: 1/20 Training loss: 0.2804
# Epochs: 1/20 Training loss: 0.2902
# Epochs: 1/20 Training loss: 0.2837
# Epochs: 1/20 Training loss: 0.2887
# Epochs: 1/20 Training loss: 0.2896
# Epochs: 1/20 Training loss: 0.2770
# Epochs: 1/20 Training loss: 0.2824
# Epochs: 1/20 Training loss: 0.2840
# Epochs: 1/20 Training loss: 0.2756
# Epochs: 1/20 Training loss: 0.2719
# Epochs: 1/20 Training loss: 0.2834
# Epochs: 1/20 Training loss: 0.2821
# Epochs: 1/20 Training loss: 0.2736
# Epochs: 1/20 Training loss: 0.2780
# Epochs: 1/20 Training loss: 0.2768
# Epochs: 1/20 Training loss: 0.2762
# Epochs: 1/20 Training loss: 0.2815
# Epochs: 1/20 Training loss: 0.2763
# Epochs: 1/20 Training loss: 0.2821
# Epochs: 1/20 Training loss: 0.2755
# Epochs: 1/20 Training loss: 0.2731
# Epochs: 1/20 Training loss: 0.2754
# Epochs: 1/20 Training loss: 0.2750
# Epochs: 1/20 Training loss: 0.2863
# Epochs: 1/20 Training loss: 0.2671
# Epochs: 1/20 Training loss: 0.2808
# Epochs: 1/20 Training loss: 0.2728
# Epochs: 1/20 Training loss: 0.2698
# Epochs: 1/20 Training loss: 0.2656
# Epochs: 1/20 Training loss: 0.2759
# Epochs: 1/20 Training loss: 0.2748
# Epochs: 1/20 Training loss: 0.2777
# Epochs: 1/20 Training loss: 0.2682
# Epochs: 1/20 Training loss: 0.2743
# Epochs: 1/20 Training loss: 0.2702
# Epochs: 1/20 Training loss: 0.2734
# Epochs: 1/20 Training loss: 0.2744
# Epochs: 1/20 Training loss: 0.2775
# Epochs: 1/20 Training loss: 0.2635
# Epochs: 1/20 Training loss: 0.2673
# Epochs: 1/20 Training loss: 0.2712
# Epochs: 1/20 Training loss: 0.2703
# Epochs: 1/20 Training loss: 0.2788
# Epochs: 1/20 Training loss: 0.2702
# Epochs: 1/20 Training loss: 0.2653
# Epochs: 1/20 Training loss: 0.2692
# Epochs: 1/20 Training loss: 0.2735
# Epochs: 1/20 Training loss: 0.2723
# Epochs: 1/20 Training loss: 0.2670
# Epochs: 1/20 Training loss: 0.2710
# Epochs: 1/20 Training loss: 0.2768
# Epochs: 1/20 Training loss: 0.2702
# Epochs: 1/20 Training loss: 0.2729
# Epochs: 1/20 Training loss: 0.2658
# Epochs: 1/20 Training loss: 0.2769
# Epochs: 1/20 Training loss: 0.2711
# Epochs: 1/20 Training loss: 0.2682
# Epochs: 1/20 Training loss: 0.2739
# Epochs: 1/20 Training loss: 0.2704
# Epochs: 1/20 Training loss: 0.2747
# Epochs: 1/20 Training loss: 0.2669
# Epochs: 1/20 Training loss: 0.2743
# Epochs: 1/20 Training loss: 0.2730
# Epochs: 1/20 Training loss: 0.2702
# Epochs: 1/20 Training loss: 0.2656
# Epochs: 1/20 Training loss: 0.2774
# Epochs: 1/20 Training loss: 0.2723
# Epochs: 1/20 Training loss: 0.2646
# Epochs: 1/20 Training loss: 0.2708
# Epochs: 1/20 Training loss: 0.2565
# Epochs: 1/20 Training loss: 0.2764
# Epochs: 1/20 Training loss: 0.2734
# Epochs: 1/20 Training loss: 0.2706
# Epochs: 1/20 Training loss: 0.2706
# Epochs: 1/20 Training loss: 0.2718
# Epochs: 1/20 Training loss: 0.2654
# Epochs: 1/20 Training loss: 0.2707
# Epochs: 1/20 Training loss: 0.2663
# Epochs: 1/20 Training loss: 0.2780
# Epochs: 1/20 Training loss: 0.2685
# Epochs: 1/20 Training loss: 0.2757
# Epochs: 1/20 Training loss: 0.2658
# Epochs: 1/20 Training loss: 0.2652
# Epochs: 1/20 Training loss: 0.2634
# Epochs: 1/20 Training loss: 0.2619
# Epochs: 1/20 Training loss: 0.2686
# Epochs: 1/20 Training loss: 0.2671
# Epochs: 1/20 Training loss: 0.2693
# Epochs: 1/20 Training loss: 0.2674
# Epochs: 1/20 Training loss: 0.2652
# Epochs: 1/20 Training loss: 0.2662
# Epochs: 1/20 Training loss: 0.2738
# Epochs: 1/20 Training loss: 0.2694
# Epochs: 1/20 Training loss: 0.2686
# Epochs: 1/20 Training loss: 0.2650
# Epochs: 1/20 Training loss: 0.2698
# Epochs: 1/20 Training loss: 0.2673
# Epochs: 1/20 Training loss: 0.2720
# Epochs: 1/20 Training loss: 0.2678
# Epochs: 1/20 Training loss: 0.2657
# Epochs: 1/20 Training loss: 0.2664
# Epochs: 1/20 Training loss: 0.2722
# Epochs: 1/20 Training loss: 0.2690
# Epochs: 1/20 Training loss: 0.2693
# Epochs: 1/20 Training loss: 0.2698
# Epochs: 1/20 Training loss: 0.2693
# Epochs: 1/20 Training loss: 0.2645
# Epochs: 1/20 Training loss: 0.2750
# Epochs: 1/20 Training loss: 0.2666
# Epochs: 1/20 Training loss: 0.2670
# Epochs: 1/20 Training loss: 0.2663
# Epochs: 1/20 Training loss: 0.2638
# Epochs: 1/20 Training loss: 0.2771
# Epochs: 1/20 Training loss: 0.2561
# Epochs: 1/20 Training loss: 0.2669
# Epochs: 1/20 Training loss: 0.2705
# Epochs: 1/20 Training loss: 0.2653
# Epochs: 1/20 Training loss: 0.2656
# Epochs: 1/20 Training loss: 0.2579
# Epochs: 1/20 Training loss: 0.2650
# Epochs: 1/20 Training loss: 0.2639
# Epochs: 1/20 Training loss: 0.2761
# Epochs: 1/20 Training loss: 0.2683
# Epochs: 1/20 Training loss: 0.2691
# Epochs: 1/20 Training loss: 0.2728
# Epochs: 1/20 Training loss: 0.2611
# Epochs: 1/20 Training loss: 0.2718
# Epochs: 1/20 Training loss: 0.2695
# Epochs: 1/20 Training loss: 0.2702
# Epochs: 1/20 Training loss: 0.2680
# Epochs: 1/20 Training loss: 0.2680
# Epochs: 1/20 Training loss: 0.2670
# Epochs: 1/20 Training loss: 0.2705
# Epochs: 1/20 Training loss: 0.2696
# Epochs: 1/20 Training loss: 0.2724
# Epochs: 1/20 Training loss: 0.2603
# Epochs: 1/20 Training loss: 0.2623
# Epochs: 1/20 Training loss: 0.2710
# Epochs: 1/20 Training loss: 0.2701
# Epochs: 1/20 Training loss: 0.2657
# Epochs: 1/20 Training loss: 0.2607
# Epochs: 1/20 Training loss: 0.2707
# Epochs: 1/20 Training loss: 0.2630
# Epochs: 1/20 Training loss: 0.2641
# Epochs: 1/20 Training loss: 0.2715
# Epochs: 1/20 Training loss: 0.2632
# Epochs: 1/20 Training loss: 0.2680
# Epochs: 1/20 Training loss: 0.2659
# Epochs: 1/20 Training loss: 0.2653
# Epochs: 1/20 Training loss: 0.2656
# Epochs: 1/20 Training loss: 0.2669
# Epochs: 1/20 Training loss: 0.2653
# Epochs: 1/20 Training loss: 0.2609
# Epochs: 1/20 Training loss: 0.2677
# Epochs: 1/20 Training loss: 0.2611
# Epochs: 1/20 Training loss: 0.2772
# Epochs: 1/20 Training loss: 0.2626
# Epochs: 1/20 Training loss: 0.2687
# Epochs: 1/20 Training loss: 0.2619
# Epochs: 1/20 Training loss: 0.2632
# Epochs: 1/20 Training loss: 0.2708
# Epochs: 1/20 Training loss: 0.2667
# Epochs: 1/20 Training loss: 0.2621
# Epochs: 1/20 Training loss: 0.2687
# Epochs: 1/20 Training loss: 0.2711
# Epochs: 1/20 Training loss: 0.2638
# Epochs: 1/20 Training loss: 0.2669
# Epochs: 1/20 Training loss: 0.2653
# Epochs: 1/20 Training loss: 0.2629
# Epochs: 1/20 Training loss: 0.2682
# Epochs: 1/20 Training loss: 0.2655
# Epochs: 1/20 Training loss: 0.2682
# Epochs: 1/20 Training loss: 0.2632
# Epochs: 1/20 Training loss: 0.2697
# Epochs: 1/20 Training loss: 0.2679
# Epochs: 1/20 Training loss: 0.2653
# Epochs: 1/20 Training loss: 0.2735
# Epochs: 1/20 Training loss: 0.2714
# Epochs: 1/20 Training loss: 0.2710
# Epochs: 1/20 Training loss: 0.2633
# Epochs: 1/20 Training loss: 0.2672
# Epochs: 1/20 Training loss: 0.2683
# Epochs: 1/20 Training loss: 0.2706
# Epochs: 1/20 Training loss: 0.2641
# Epochs: 1/20 Training loss: 0.2662
# Epochs: 1/20 Training loss: 0.2658
# Epochs: 1/20 Training loss: 0.2563
# Epochs: 1/20 Training loss: 0.2684
# Epochs: 1/20 Training loss: 0.2598
# Epochs: 1/20 Training loss: 0.2629
# Epochs: 1/20 Training loss: 0.2635
# Epochs: 1/20 Training loss: 0.2585
# Epochs: 1/20 Training loss: 0.2692
# Epochs: 1/20 Training loss: 0.2695
# Epochs: 1/20 Training loss: 0.2649
# Epochs: 1/20 Training loss: 0.2700
# Epochs: 1/20 Training loss: 0.2639
# Epochs: 1/20 Training loss: 0.2648
# Epochs: 1/20 Training loss: 0.2673
# Epochs: 1/20 Training loss: 0.2623
# Epochs: 1/20 Training loss: 0.2615
# Epochs: 1/20 Training loss: 0.2699
# Epochs: 1/20 Training loss: 0.2652
# Epochs: 1/20 Training loss: 0.2701
# Epochs: 1/20 Training loss: 0.2608
# Epochs: 1/20 Training loss: 0.2743
# Epochs: 1/20 Training loss: 0.2637
# Epochs: 1/20 Training loss: 0.2709
# Epochs: 1/20 Training loss: 0.2635
# Epochs: 1/20 Training loss: 0.2615
# Epochs: 1/20 Training loss: 0.2600
# Epochs: 1/20 Training loss: 0.2605
# Epochs: 1/20 Training loss: 0.2589
# Epochs: 1/20 Training loss: 0.2726
# Epochs: 1/20 Training loss: 0.2690
# Epochs: 1/20 Training loss: 0.2642
# Epochs: 1/20 Training loss: 0.2705
# Epochs: 1/20 Training loss: 0.2612
# Epochs: 1/20 Training loss: 0.2660
# Epochs: 1/20 Training loss: 0.2728
# Epochs: 1/20 Training loss: 0.2625
# Epochs: 1/20 Training loss: 0.2710
# Epochs: 1/20 Training loss: 0.2638
# Epochs: 1/20 Training loss: 0.2667
# Epochs: 1/20 Training loss: 0.2569
# Epochs: 1/20 Training loss: 0.2672
# Epochs: 1/20 Training loss: 0.2683
# Epochs: 1/20 Training loss: 0.2746
# Epochs: 1/20 Training loss: 0.2645
# Epochs: 1/20 Training loss: 0.2666
# Epochs: 1/20 Training loss: 0.2582
# Epochs: 1/20 Training loss: 0.2669
# Epochs: 1/20 Training loss: 0.2595
# Epochs: 1/20 Training loss: 0.2629
# Epochs: 1/20 Training loss: 0.2726
# Epochs: 2/20 Training loss: 0.2625
# Epochs: 2/20 Training loss: 0.2702
# Epochs: 2/20 Training loss: 0.2709
# Epochs: 2/20 Training loss: 0.2650
# Epochs: 2/20 Training loss: 0.2697
# Epochs: 2/20 Training loss: 0.2730
# Epochs: 2/20 Training loss: 0.2667
# Epochs: 2/20 Training loss: 0.2625
# Epochs: 2/20 Training loss: 0.2614
# Epochs: 2/20 Training loss: 0.2681
# Epochs: 2/20 Training loss: 0.2611
# Epochs: 2/20 Training loss: 0.2646
# Epochs: 2/20 Training loss: 0.2638
# Epochs: 2/20 Training loss: 0.2730
# Epochs: 2/20 Training loss: 0.2632
# Epochs: 2/20 Training loss: 0.2692
# Epochs: 2/20 Training loss: 0.2679
# Epochs: 2/20 Training loss: 0.2642
# Epochs: 2/20 Training loss: 0.2677
# Epochs: 2/20 Training loss: 0.2673
# Epochs: 2/20 Training loss: 0.2681
# Epochs: 2/20 Training loss: 0.2656
# Epochs: 2/20 Training loss: 0.2635
# Epochs: 2/20 Training loss: 0.2710
# Epochs: 2/20 Training loss: 0.2587
# Epochs: 2/20 Training loss: 0.2663
# Epochs: 2/20 Training loss: 0.2632
# Epochs: 2/20 Training loss: 0.2606
# Epochs: 2/20 Training loss: 0.2686
# Epochs: 2/20 Training loss: 0.2643
# Epochs: 2/20 Training loss: 0.2633
# Epochs: 2/20 Training loss: 0.2640
# Epochs: 2/20 Training loss: 0.2652
# Epochs: 2/20 Training loss: 0.2627
# Epochs: 2/20 Training loss: 0.2629
# Epochs: 2/20 Training loss: 0.2656
# Epochs: 2/20 Training loss: 0.2631
# Epochs: 2/20 Training loss: 0.2638
# Epochs: 2/20 Training loss: 0.2666
# Epochs: 2/20 Training loss: 0.2723
# Epochs: 2/20 Training loss: 0.2621
# Epochs: 2/20 Training loss: 0.2598
# Epochs: 2/20 Training loss: 0.2597
# Epochs: 2/20 Training loss: 0.2647
# Epochs: 2/20 Training loss: 0.2684
# Epochs: 2/20 Training loss: 0.2674
# Epochs: 2/20 Training loss: 0.2613
# Epochs: 2/20 Training loss: 0.2724
# Epochs: 2/20 Training loss: 0.2725
# Epochs: 2/20 Training loss: 0.2667
# Epochs: 2/20 Training loss: 0.2619
# Epochs: 2/20 Training loss: 0.2606
# Epochs: 2/20 Training loss: 0.2643
# Epochs: 2/20 Training loss: 0.2628
# Epochs: 2/20 Training loss: 0.2760
# Epochs: 2/20 Training loss: 0.2663
# Epochs: 2/20 Training loss: 0.2616
# Epochs: 2/20 Training loss: 0.2626
# Epochs: 2/20 Training loss: 0.2668
# Epochs: 2/20 Training loss: 0.2639
# Epochs: 2/20 Training loss: 0.2677
# Epochs: 2/20 Training loss: 0.2642
# Epochs: 2/20 Training loss: 0.2668
# Epochs: 2/20 Training loss: 0.2688
# Epochs: 2/20 Training loss: 0.2700
# Epochs: 2/20 Training loss: 0.2712
# Epochs: 2/20 Training loss: 0.2668
# Epochs: 2/20 Training loss: 0.2674
# Epochs: 2/20 Training loss: 0.2718
# Epochs: 2/20 Training loss: 0.2624
# Epochs: 2/20 Training loss: 0.2641
# Epochs: 2/20 Training loss: 0.2696
# Epochs: 2/20 Training loss: 0.2731
# Epochs: 2/20 Training loss: 0.2689
# Epochs: 2/20 Training loss: 0.2644
# Epochs: 2/20 Training loss: 0.2736
# Epochs: 2/20 Training loss: 0.2661
# Epochs: 2/20 Training loss: 0.2641
# Epochs: 2/20 Training loss: 0.2657
# Epochs: 2/20 Training loss: 0.2712
# Epochs: 2/20 Training loss: 0.2742
# Epochs: 2/20 Training loss: 0.2676
# Epochs: 2/20 Training loss: 0.2693
# Epochs: 2/20 Training loss: 0.2645
# Epochs: 2/20 Training loss: 0.2667
# Epochs: 2/20 Training loss: 0.2647
# Epochs: 2/20 Training loss: 0.2696
# Epochs: 2/20 Training loss: 0.2637
# Epochs: 2/20 Training loss: 0.2632
# Epochs: 2/20 Training loss: 0.2627
# Epochs: 2/20 Training loss: 0.2629
# Epochs: 2/20 Training loss: 0.2650
# Epochs: 2/20 Training loss: 0.2603
# Epochs: 2/20 Training loss: 0.2670
# Epochs: 2/20 Training loss: 0.2659
# Epochs: 2/20 Training loss: 0.2692
# Epochs: 2/20 Training loss: 0.2646
# Epochs: 2/20 Training loss: 0.2634
# Epochs: 2/20 Training loss: 0.2683
# Epochs: 2/20 Training loss: 0.2662
# Epochs: 2/20 Training loss: 0.2671
# Epochs: 2/20 Training loss: 0.2604
# Epochs: 2/20 Training loss: 0.2620
# Epochs: 2/20 Training loss: 0.2614
# Epochs: 2/20 Training loss: 0.2639
# Epochs: 2/20 Training loss: 0.2654
# Epochs: 2/20 Training loss: 0.2667
# Epochs: 2/20 Training loss: 0.2583
# Epochs: 2/20 Training loss: 0.2676
# Epochs: 2/20 Training loss: 0.2605
# Epochs: 2/20 Training loss: 0.2717
# Epochs: 2/20 Training loss: 0.2711
# Epochs: 2/20 Training loss: 0.2702
# Epochs: 2/20 Training loss: 0.2670
# Epochs: 2/20 Training loss: 0.2593
# Epochs: 2/20 Training loss: 0.2613
# Epochs: 2/20 Training loss: 0.2634
# Epochs: 2/20 Training loss: 0.2688
# Epochs: 2/20 Training loss: 0.2724
# Epochs: 2/20 Training loss: 0.2583
# Epochs: 2/20 Training loss: 0.2754
# Epochs: 2/20 Training loss: 0.2599
# Epochs: 2/20 Training loss: 0.2673
# Epochs: 2/20 Training loss: 0.2645
# Epochs: 2/20 Training loss: 0.2638
# Epochs: 2/20 Training loss: 0.2707
# Epochs: 2/20 Training loss: 0.2632
# Epochs: 2/20 Training loss: 0.2609
# Epochs: 2/20 Training loss: 0.2655
# Epochs: 2/20 Training loss: 0.2718
# Epochs: 2/20 Training loss: 0.2628
# Epochs: 2/20 Training loss: 0.2635
# Epochs: 2/20 Training loss: 0.2692
# Epochs: 2/20 Training loss: 0.2608
# Epochs: 2/20 Training loss: 0.2575
# Epochs: 2/20 Training loss: 0.2612
# Epochs: 2/20 Training loss: 0.2637
# Epochs: 2/20 Training loss: 0.2634
# Epochs: 2/20 Training loss: 0.2667
# Epochs: 2/20 Training loss: 0.2661
# Epochs: 2/20 Training loss: 0.2695
# Epochs: 2/20 Training loss: 0.2657
# Epochs: 2/20 Training loss: 0.2672
# Epochs: 2/20 Training loss: 0.2674
# Epochs: 2/20 Training loss: 0.2655
# Epochs: 2/20 Training loss: 0.2616
# Epochs: 2/20 Training loss: 0.2693
# Epochs: 2/20 Training loss: 0.2645
# Epochs: 2/20 Training loss: 0.2670
# Epochs: 2/20 Training loss: 0.2646
# Epochs: 2/20 Training loss: 0.2663
# Epochs: 2/20 Training loss: 0.2646
# Epochs: 2/20 Training loss: 0.2643
# Epochs: 2/20 Training loss: 0.2575
# Epochs: 2/20 Training loss: 0.2610
# Epochs: 2/20 Training loss: 0.2580
# Epochs: 2/20 Training loss: 0.2667
# Epochs: 2/20 Training loss: 0.2650
# Epochs: 2/20 Training loss: 0.2562
# Epochs: 2/20 Training loss: 0.2591
# Epochs: 2/20 Training loss: 0.2657
# Epochs: 2/20 Training loss: 0.2643
# Epochs: 2/20 Training loss: 0.2664
# Epochs: 2/20 Training loss: 0.2580
# Epochs: 2/20 Training loss: 0.2626
# Epochs: 2/20 Training loss: 0.2691
# Epochs: 2/20 Training loss: 0.2661
# Epochs: 2/20 Training loss: 0.2629
# Epochs: 2/20 Training loss: 0.2633
# Epochs: 2/20 Training loss: 0.2653
# Epochs: 2/20 Training loss: 0.2599
# Epochs: 2/20 Training loss: 0.2688
# Epochs: 2/20 Training loss: 0.2628
# Epochs: 2/20 Training loss: 0.2681
# Epochs: 2/20 Training loss: 0.2671
# Epochs: 2/20 Training loss: 0.2707
# Epochs: 2/20 Training loss: 0.2619
# Epochs: 2/20 Training loss: 0.2595
# Epochs: 2/20 Training loss: 0.2650
# Epochs: 2/20 Training loss: 0.2744
# Epochs: 2/20 Training loss: 0.2674
# Epochs: 2/20 Training loss: 0.2626
# Epochs: 2/20 Training loss: 0.2592
# Epochs: 2/20 Training loss: 0.2668
# Epochs: 2/20 Training loss: 0.2659
# Epochs: 2/20 Training loss: 0.2573
# Epochs: 2/20 Training loss: 0.2532
# Epochs: 2/20 Training loss: 0.2684
# Epochs: 2/20 Training loss: 0.2606
# Epochs: 2/20 Training loss: 0.2618
# Epochs: 2/20 Training loss: 0.2655
# Epochs: 2/20 Training loss: 0.2680
# Epochs: 2/20 Training loss: 0.2590
# Epochs: 2/20 Training loss: 0.2676
# Epochs: 2/20 Training loss: 0.2620
# Epochs: 2/20 Training loss: 0.2747
# Epochs: 2/20 Training loss: 0.2677
# Epochs: 2/20 Training loss: 0.2652
# Epochs: 2/20 Training loss: 0.2572
# Epochs: 2/20 Training loss: 0.2702
# Epochs: 2/20 Training loss: 0.2599
# Epochs: 2/20 Training loss: 0.2618
# Epochs: 2/20 Training loss: 0.2712
# Epochs: 2/20 Training loss: 0.2659
# Epochs: 2/20 Training loss: 0.2660
# Epochs: 2/20 Training loss: 0.2592
# Epochs: 2/20 Training loss: 0.2625
# Epochs: 2/20 Training loss: 0.2664
# Epochs: 2/20 Training loss: 0.2678
# Epochs: 2/20 Training loss: 0.2616
# Epochs: 2/20 Training loss: 0.2650
# Epochs: 2/20 Training loss: 0.2599
# Epochs: 2/20 Training loss: 0.2641
# Epochs: 2/20 Training loss: 0.2659
# Epochs: 2/20 Training loss: 0.2671
# Epochs: 2/20 Training loss: 0.2639
# Epochs: 2/20 Training loss: 0.2555
# Epochs: 2/20 Training loss: 0.2576
# Epochs: 2/20 Training loss: 0.2702
# Epochs: 2/20 Training loss: 0.2630
# Epochs: 2/20 Training loss: 0.2704
# Epochs: 2/20 Training loss: 0.2612
# Epochs: 2/20 Training loss: 0.2582
# Epochs: 2/20 Training loss: 0.2677
# Epochs: 2/20 Training loss: 0.2590
# Epochs: 2/20 Training loss: 0.2689
# Epochs: 2/20 Training loss: 0.2705
# Epochs: 2/20 Training loss: 0.2616
# Epochs: 2/20 Training loss: 0.2662
# Epochs: 2/20 Training loss: 0.2678
# Epochs: 2/20 Training loss: 0.2665
# Epochs: 2/20 Training loss: 0.2549
# Epochs: 2/20 Training loss: 0.2676
# Epochs: 2/20 Training loss: 0.2611
# Epochs: 2/20 Training loss: 0.2722
# Epochs: 2/20 Training loss: 0.2658
# Epochs: 2/20 Training loss: 0.2685
# Epochs: 2/20 Training loss: 0.2616
# Epochs: 2/20 Training loss: 0.2658
# Epochs: 2/20 Training loss: 0.2669
# Epochs: 2/20 Training loss: 0.2642
# Epochs: 2/20 Training loss: 0.2662
# Epochs: 2/20 Training loss: 0.2671
# Epochs: 2/20 Training loss: 0.2680
# Epochs: 2/20 Training loss: 0.2641
# Epochs: 2/20 Training loss: 0.2629
# Epochs: 2/20 Training loss: 0.2638
# Epochs: 2/20 Training loss: 0.2596
# Epochs: 2/20 Training loss: 0.2660
# Epochs: 2/20 Training loss: 0.2578
# Epochs: 2/20 Training loss: 0.2684
# Epochs: 2/20 Training loss: 0.2633
# Epochs: 2/20 Training loss: 0.2613
# Epochs: 2/20 Training loss: 0.2648
# Epochs: 2/20 Training loss: 0.2687
# Epochs: 2/20 Training loss: 0.2675
# Epochs: 2/20 Training loss: 0.2662
# Epochs: 2/20 Training loss: 0.2655
# Epochs: 2/20 Training loss: 0.2685
# Epochs: 2/20 Training loss: 0.2634
# Epochs: 2/20 Training loss: 0.2680
# Epochs: 2/20 Training loss: 0.2653
# Epochs: 2/20 Training loss: 0.2681
# Epochs: 2/20 Training loss: 0.2611
# Epochs: 2/20 Training loss: 0.2595
# Epochs: 2/20 Training loss: 0.2627
# Epochs: 2/20 Training loss: 0.2575
# Epochs: 2/20 Training loss: 0.2659
# Epochs: 2/20 Training loss: 0.2709
# Epochs: 2/20 Training loss: 0.2627
# Epochs: 2/20 Training loss: 0.2704
# Epochs: 2/20 Training loss: 0.2643
# Epochs: 2/20 Training loss: 0.2675
# Epochs: 2/20 Training loss: 0.2664
# Epochs: 2/20 Training loss: 0.2607
# Epochs: 2/20 Training loss: 0.2608
# Epochs: 2/20 Training loss: 0.2658
# Epochs: 2/20 Training loss: 0.2636
# Epochs: 2/20 Training loss: 0.2640
# Epochs: 2/20 Training loss: 0.2699
# Epochs: 2/20 Training loss: 0.2716
# Epochs: 2/20 Training loss: 0.2613
# Epochs: 2/20 Training loss: 0.2625
# Epochs: 2/20 Training loss: 0.2675
# Epochs: 2/20 Training loss: 0.2637
# Epochs: 2/20 Training loss: 0.2717
# Epochs: 2/20 Training loss: 0.2613
# Epochs: 2/20 Training loss: 0.2644
# Epochs: 2/20 Training loss: 0.2646
# Epochs: 2/20 Training loss: 0.2609
# Epochs: 2/20 Training loss: 0.2693
# Epochs: 2/20 Training loss: 0.2588
# Epochs: 2/20 Training loss: 0.2598
# Epochs: 2/20 Training loss: 0.2608
# Epochs: 2/20 Training loss: 0.2586
# Epochs: 2/20 Training loss: 0.2655
# Epochs: 2/20 Training loss: 0.2685
# Epochs: 2/20 Training loss: 0.2599
# Epochs: 2/20 Training loss: 0.2665
# Epochs: 2/20 Training loss: 0.2630
# Epochs: 3/20 Training loss: 0.2564
# Epochs: 3/20 Training loss: 0.2629
# Epochs: 3/20 Training loss: 0.2650
# Epochs: 3/20 Training loss: 0.2706
# Epochs: 3/20 Training loss: 0.2577
# Epochs: 3/20 Training loss: 0.2651
# Epochs: 3/20 Training loss: 0.2617
# Epochs: 3/20 Training loss: 0.2701
# Epochs: 3/20 Training loss: 0.2574
# Epochs: 3/20 Training loss: 0.2610
# Epochs: 3/20 Training loss: 0.2647
# Epochs: 3/20 Training loss: 0.2599
# Epochs: 3/20 Training loss: 0.2621
# Epochs: 3/20 Training loss: 0.2664
# Epochs: 3/20 Training loss: 0.2602
# Epochs: 3/20 Training loss: 0.2632
# Epochs: 3/20 Training loss: 0.2670
# Epochs: 3/20 Training loss: 0.2593
# Epochs: 3/20 Training loss: 0.2608
# Epochs: 3/20 Training loss: 0.2664
# Epochs: 3/20 Training loss: 0.2675
# Epochs: 3/20 Training loss: 0.2706
# Epochs: 3/20 Training loss: 0.2637
# Epochs: 3/20 Training loss: 0.2617
# Epochs: 3/20 Training loss: 0.2580
# Epochs: 3/20 Training loss: 0.2682
# Epochs: 3/20 Training loss: 0.2687
# Epochs: 3/20 Training loss: 0.2662
# Epochs: 3/20 Training loss: 0.2627
# Epochs: 3/20 Training loss: 0.2725
# Epochs: 3/20 Training loss: 0.2683
# Epochs: 3/20 Training loss: 0.2701
# Epochs: 3/20 Training loss: 0.2710
# Epochs: 3/20 Training loss: 0.2576
# Epochs: 3/20 Training loss: 0.2661
# Epochs: 3/20 Training loss: 0.2632
# Epochs: 3/20 Training loss: 0.2659
# Epochs: 3/20 Training loss: 0.2659
# Epochs: 3/20 Training loss: 0.2663
# Epochs: 3/20 Training loss: 0.2645
# Epochs: 3/20 Training loss: 0.2696
# Epochs: 3/20 Training loss: 0.2659
# Epochs: 3/20 Training loss: 0.2680
# Epochs: 3/20 Training loss: 0.2651
# Epochs: 3/20 Training loss: 0.2707
# Epochs: 3/20 Training loss: 0.2600
# Epochs: 3/20 Training loss: 0.2610
# Epochs: 3/20 Training loss: 0.2605
# Epochs: 3/20 Training loss: 0.2649
# Epochs: 3/20 Training loss: 0.2639
# Epochs: 3/20 Training loss: 0.2674
# Epochs: 3/20 Training loss: 0.2619
# Epochs: 3/20 Training loss: 0.2680
# Epochs: 3/20 Training loss: 0.2639
# Epochs: 3/20 Training loss: 0.2622
# Epochs: 3/20 Training loss: 0.2667
# Epochs: 3/20 Training loss: 0.2653
# Epochs: 3/20 Training loss: 0.2684
# Epochs: 3/20 Training loss: 0.2622
# Epochs: 3/20 Training loss: 0.2556
# Epochs: 3/20 Training loss: 0.2649
# Epochs: 3/20 Training loss: 0.2634
# Epochs: 3/20 Training loss: 0.2641
# Epochs: 3/20 Training loss: 0.2624
# Epochs: 3/20 Training loss: 0.2659
# Epochs: 3/20 Training loss: 0.2597
# Epochs: 3/20 Training loss: 0.2702
# Epochs: 3/20 Training loss: 0.2662
# Epochs: 3/20 Training loss: 0.2626
# Epochs: 3/20 Training loss: 0.2613
# Epochs: 3/20 Training loss: 0.2618
# Epochs: 3/20 Training loss: 0.2705
# Epochs: 3/20 Training loss: 0.2667
# Epochs: 3/20 Training loss: 0.2602
# Epochs: 3/20 Training loss: 0.2615
# Epochs: 3/20 Training loss: 0.2660
# Epochs: 3/20 Training loss: 0.2697
# Epochs: 3/20 Training loss: 0.2709
# Epochs: 3/20 Training loss: 0.2685
# Epochs: 3/20 Training loss: 0.2581
# Epochs: 3/20 Training loss: 0.2641
# Epochs: 3/20 Training loss: 0.2672
# Epochs: 3/20 Training loss: 0.2695
# Epochs: 3/20 Training loss: 0.2662
# Epochs: 3/20 Training loss: 0.2651
# Epochs: 3/20 Training loss: 0.2613
# Epochs: 3/20 Training loss: 0.2617
# Epochs: 3/20 Training loss: 0.2719
# Epochs: 3/20 Training loss: 0.2629
# Epochs: 3/20 Training loss: 0.2623
# Epochs: 3/20 Training loss: 0.2616
# Epochs: 3/20 Training loss: 0.2664
# Epochs: 3/20 Training loss: 0.2641
# Epochs: 3/20 Training loss: 0.2548
# Epochs: 3/20 Training loss: 0.2642
# Epochs: 3/20 Training loss: 0.2640
# Epochs: 3/20 Training loss: 0.2656
# Epochs: 3/20 Training loss: 0.2671
# Epochs: 3/20 Training loss: 0.2664
# Epochs: 3/20 Training loss: 0.2634
# Epochs: 3/20 Training loss: 0.2670
# Epochs: 3/20 Training loss: 0.2641
# Epochs: 3/20 Training loss: 0.2594
# Epochs: 3/20 Training loss: 0.2639
# Epochs: 3/20 Training loss: 0.2567
# Epochs: 3/20 Training loss: 0.2579
# Epochs: 3/20 Training loss: 0.2648
# Epochs: 3/20 Training loss: 0.2630
# Epochs: 3/20 Training loss: 0.2643
# Epochs: 3/20 Training loss: 0.2632
# Epochs: 3/20 Training loss: 0.2696
# Epochs: 3/20 Training loss: 0.2677
# Epochs: 3/20 Training loss: 0.2614
# Epochs: 3/20 Training loss: 0.2603
# Epochs: 3/20 Training loss: 0.2620
# Epochs: 3/20 Training loss: 0.2692
# Epochs: 3/20 Training loss: 0.2752
# Epochs: 3/20 Training loss: 0.2630
# Epochs: 3/20 Training loss: 0.2633
# Epochs: 3/20 Training loss: 0.2634
# Epochs: 3/20 Training loss: 0.2594
# Epochs: 3/20 Training loss: 0.2616
# Epochs: 3/20 Training loss: 0.2640
# Epochs: 3/20 Training loss: 0.2688
# Epochs: 3/20 Training loss: 0.2674
# Epochs: 3/20 Training loss: 0.2654
# Epochs: 3/20 Training loss: 0.2629
# Epochs: 3/20 Training loss: 0.2607
# Epochs: 3/20 Training loss: 0.2625
# Epochs: 3/20 Training loss: 0.2682
# Epochs: 3/20 Training loss: 0.2655
# Epochs: 3/20 Training loss: 0.2621
# Epochs: 3/20 Training loss: 0.2621
# Epochs: 3/20 Training loss: 0.2636
# Epochs: 3/20 Training loss: 0.2642
# Epochs: 3/20 Training loss: 0.2706
# Epochs: 3/20 Training loss: 0.2710
# Epochs: 3/20 Training loss: 0.2715
# Epochs: 3/20 Training loss: 0.2682
# Epochs: 3/20 Training loss: 0.2664
# Epochs: 3/20 Training loss: 0.2641
# Epochs: 3/20 Training loss: 0.2681
# Epochs: 3/20 Training loss: 0.2632
# Epochs: 3/20 Training loss: 0.2650
# Epochs: 3/20 Training loss: 0.2699
# Epochs: 3/20 Training loss: 0.2718
# Epochs: 3/20 Training loss: 0.2640
# Epochs: 3/20 Training loss: 0.2661
# Epochs: 3/20 Training loss: 0.2676
# Epochs: 3/20 Training loss: 0.2654
# Epochs: 3/20 Training loss: 0.2627
# Epochs: 3/20 Training loss: 0.2673
# Epochs: 3/20 Training loss: 0.2700
# Epochs: 3/20 Training loss: 0.2627
# Epochs: 3/20 Training loss: 0.2637
# Epochs: 3/20 Training loss: 0.2595
# Epochs: 3/20 Training loss: 0.2644
# Epochs: 3/20 Training loss: 0.2685
# Epochs: 3/20 Training loss: 0.2630
# Epochs: 3/20 Training loss: 0.2589
# Epochs: 3/20 Training loss: 0.2655
# Epochs: 3/20 Training loss: 0.2662
# Epochs: 3/20 Training loss: 0.2677
# Epochs: 3/20 Training loss: 0.2643
# Epochs: 3/20 Training loss: 0.2687
# Epochs: 3/20 Training loss: 0.2591
# Epochs: 3/20 Training loss: 0.2676
# Epochs: 3/20 Training loss: 0.2623
# Epochs: 3/20 Training loss: 0.2638
# Epochs: 3/20 Training loss: 0.2652
# Epochs: 3/20 Training loss: 0.2592
# Epochs: 3/20 Training loss: 0.2637
# Epochs: 3/20 Training loss: 0.2640
# Epochs: 3/20 Training loss: 0.2632
# Epochs: 3/20 Training loss: 0.2616
# Epochs: 3/20 Training loss: 0.2658
# Epochs: 3/20 Training loss: 0.2608
# Epochs: 3/20 Training loss: 0.2751
# Epochs: 3/20 Training loss: 0.2673
# Epochs: 3/20 Training loss: 0.2684
# Epochs: 3/20 Training loss: 0.2624
# Epochs: 3/20 Training loss: 0.2651
# Epochs: 3/20 Training loss: 0.2627
# Epochs: 3/20 Training loss: 0.2586
# Epochs: 3/20 Training loss: 0.2633
# Epochs: 3/20 Training loss: 0.2701
# Epochs: 3/20 Training loss: 0.2593
# Epochs: 3/20 Training loss: 0.2667
# Epochs: 3/20 Training loss: 0.2647
# Epochs: 3/20 Training loss: 0.2620
# Epochs: 3/20 Training loss: 0.2635
# Epochs: 3/20 Training loss: 0.2649
# Epochs: 3/20 Training loss: 0.2665
# Epochs: 3/20 Training loss: 0.2690
# Epochs: 3/20 Training loss: 0.2667
# Epochs: 3/20 Training loss: 0.2696
# Epochs: 3/20 Training loss: 0.2636
# Epochs: 3/20 Training loss: 0.2623
# Epochs: 3/20 Training loss: 0.2688
# Epochs: 3/20 Training loss: 0.2617
# Epochs: 3/20 Training loss: 0.2610
# Epochs: 3/20 Training loss: 0.2686
# Epochs: 3/20 Training loss: 0.2605
# Epochs: 3/20 Training loss: 0.2664
# Epochs: 3/20 Training loss: 0.2548
# Epochs: 3/20 Training loss: 0.2646
# Epochs: 3/20 Training loss: 0.2678
# Epochs: 3/20 Training loss: 0.2688
# Epochs: 3/20 Training loss: 0.2703
# Epochs: 3/20 Training loss: 0.2661
# Epochs: 3/20 Training loss: 0.2693
# Epochs: 3/20 Training loss: 0.2626
# Epochs: 3/20 Training loss: 0.2604
# Epochs: 3/20 Training loss: 0.2622
# Epochs: 3/20 Training loss: 0.2621
# Epochs: 3/20 Training loss: 0.2689
# Epochs: 3/20 Training loss: 0.2644
# Epochs: 3/20 Training loss: 0.2627
# Epochs: 3/20 Training loss: 0.2635
# Epochs: 3/20 Training loss: 0.2627
# Epochs: 3/20 Training loss: 0.2616
# Epochs: 3/20 Training loss: 0.2585
# Epochs: 3/20 Training loss: 0.2660
# Epochs: 3/20 Training loss: 0.2595
# Epochs: 3/20 Training loss: 0.2663
# Epochs: 3/20 Training loss: 0.2640
# Epochs: 3/20 Training loss: 0.2679
# Epochs: 3/20 Training loss: 0.2669
# Epochs: 3/20 Training loss: 0.2623
# Epochs: 3/20 Training loss: 0.2670
# Epochs: 3/20 Training loss: 0.2627
# Epochs: 3/20 Training loss: 0.2627
# Epochs: 3/20 Training loss: 0.2652
# Epochs: 3/20 Training loss: 0.2645
# Epochs: 3/20 Training loss: 0.2620
# Epochs: 3/20 Training loss: 0.2606
# Epochs: 3/20 Training loss: 0.2660
# Epochs: 3/20 Training loss: 0.2668
# Epochs: 3/20 Training loss: 0.2599
# Epochs: 3/20 Training loss: 0.2662
# Epochs: 3/20 Training loss: 0.2616
# Epochs: 3/20 Training loss: 0.2638
# Epochs: 3/20 Training loss: 0.2650
# Epochs: 3/20 Training loss: 0.2704
# Epochs: 3/20 Training loss: 0.2651
# Epochs: 3/20 Training loss: 0.2595
# Epochs: 3/20 Training loss: 0.2652
# Epochs: 3/20 Training loss: 0.2675
# Epochs: 3/20 Training loss: 0.2621
# Epochs: 3/20 Training loss: 0.2577
# Epochs: 3/20 Training loss: 0.2597
# Epochs: 3/20 Training loss: 0.2630
# Epochs: 3/20 Training loss: 0.2594
# Epochs: 3/20 Training loss: 0.2697
# Epochs: 3/20 Training loss: 0.2695
# Epochs: 3/20 Training loss: 0.2663
# Epochs: 3/20 Training loss: 0.2690
# Epochs: 3/20 Training loss: 0.2679
# Epochs: 3/20 Training loss: 0.2654
# Epochs: 3/20 Training loss: 0.2656
# Epochs: 3/20 Training loss: 0.2646
# Epochs: 3/20 Training loss: 0.2588
# Epochs: 3/20 Training loss: 0.2672
# Epochs: 3/20 Training loss: 0.2649
# Epochs: 3/20 Training loss: 0.2596
# Epochs: 3/20 Training loss: 0.2528
# Epochs: 3/20 Training loss: 0.2578
# Epochs: 3/20 Training loss: 0.2691
# Epochs: 3/20 Training loss: 0.2731
# Epochs: 3/20 Training loss: 0.2692
# Epochs: 3/20 Training loss: 0.2694
# Epochs: 3/20 Training loss: 0.2632
# Epochs: 3/20 Training loss: 0.2664
# Epochs: 3/20 Training loss: 0.2588
# Epochs: 3/20 Training loss: 0.2631
# Epochs: 3/20 Training loss: 0.2702
# Epochs: 3/20 Training loss: 0.2625
# Epochs: 3/20 Training loss: 0.2697
# Epochs: 3/20 Training loss: 0.2644
# Epochs: 3/20 Training loss: 0.2637
# Epochs: 3/20 Training loss: 0.2628
# Epochs: 3/20 Training loss: 0.2688
# Epochs: 3/20 Training loss: 0.2607
# Epochs: 3/20 Training loss: 0.2530
# Epochs: 3/20 Training loss: 0.2655
# Epochs: 3/20 Training loss: 0.2611
# Epochs: 3/20 Training loss: 0.2658
# Epochs: 3/20 Training loss: 0.2715
# Epochs: 3/20 Training loss: 0.2603
# Epochs: 3/20 Training loss: 0.2577
# Epochs: 3/20 Training loss: 0.2602
# Epochs: 3/20 Training loss: 0.2570
# Epochs: 3/20 Training loss: 0.2723
# Epochs: 3/20 Training loss: 0.2681
# Epochs: 3/20 Training loss: 0.2634
# Epochs: 3/20 Training loss: 0.2590
# Epochs: 3/20 Training loss: 0.2636
# Epochs: 3/20 Training loss: 0.2629
# Epochs: 3/20 Training loss: 0.2605
# Epochs: 3/20 Training loss: 0.2620
# Epochs: 4/20 Training loss: 0.2690
# Epochs: 4/20 Training loss: 0.2706
# Epochs: 4/20 Training loss: 0.2743
# Epochs: 4/20 Training loss: 0.2713
# Epochs: 4/20 Training loss: 0.2693
# Epochs: 4/20 Training loss: 0.2611
# Epochs: 4/20 Training loss: 0.2656
# Epochs: 4/20 Training loss: 0.2598
# Epochs: 4/20 Training loss: 0.2602
# Epochs: 4/20 Training loss: 0.2667
# Epochs: 4/20 Training loss: 0.2674
# Epochs: 4/20 Training loss: 0.2642
# Epochs: 4/20 Training loss: 0.2674
# Epochs: 4/20 Training loss: 0.2711
# Epochs: 4/20 Training loss: 0.2644
# Epochs: 4/20 Training loss: 0.2685
# Epochs: 4/20 Training loss: 0.2648
# Epochs: 4/20 Training loss: 0.2643
# Epochs: 4/20 Training loss: 0.2635
# Epochs: 4/20 Training loss: 0.2687
# Epochs: 4/20 Training loss: 0.2697
# Epochs: 4/20 Training loss: 0.2639
# Epochs: 4/20 Training loss: 0.2647
# Epochs: 4/20 Training loss: 0.2681
# Epochs: 4/20 Training loss: 0.2635
# Epochs: 4/20 Training loss: 0.2623
# Epochs: 4/20 Training loss: 0.2645
# Epochs: 4/20 Training loss: 0.2646
# Epochs: 4/20 Training loss: 0.2721
# Epochs: 4/20 Training loss: 0.2627
# Epochs: 4/20 Training loss: 0.2711
# Epochs: 4/20 Training loss: 0.2643
# Epochs: 4/20 Training loss: 0.2640
# Epochs: 4/20 Training loss: 0.2684
# Epochs: 4/20 Training loss: 0.2654
# Epochs: 4/20 Training loss: 0.2682
# Epochs: 4/20 Training loss: 0.2689
# Epochs: 4/20 Training loss: 0.2562
# Epochs: 4/20 Training loss: 0.2637
# Epochs: 4/20 Training loss: 0.2543
# Epochs: 4/20 Training loss: 0.2636
# Epochs: 4/20 Training loss: 0.2562
# Epochs: 4/20 Training loss: 0.2702
# Epochs: 4/20 Training loss: 0.2644
# Epochs: 4/20 Training loss: 0.2655
# Epochs: 4/20 Training loss: 0.2651
# Epochs: 4/20 Training loss: 0.2601
# Epochs: 4/20 Training loss: 0.2637
# Epochs: 4/20 Training loss: 0.2640
# Epochs: 4/20 Training loss: 0.2621
# Epochs: 4/20 Training loss: 0.2651
# Epochs: 4/20 Training loss: 0.2600
# Epochs: 4/20 Training loss: 0.2740
# Epochs: 4/20 Training loss: 0.2637
# Epochs: 4/20 Training loss: 0.2658
# Epochs: 4/20 Training loss: 0.2653
# Epochs: 4/20 Training loss: 0.2598
# Epochs: 4/20 Training loss: 0.2719
# Epochs: 4/20 Training loss: 0.2614
# Epochs: 4/20 Training loss: 0.2692
# Epochs: 4/20 Training loss: 0.2614
# Epochs: 4/20 Training loss: 0.2647
# Epochs: 4/20 Training loss: 0.2673
# Epochs: 4/20 Training loss: 0.2568
# Epochs: 4/20 Training loss: 0.2655
# Epochs: 4/20 Training loss: 0.2653
# Epochs: 4/20 Training loss: 0.2627
# Epochs: 4/20 Training loss: 0.2640
# Epochs: 4/20 Training loss: 0.2669
# Epochs: 4/20 Training loss: 0.2637
# Epochs: 4/20 Training loss: 0.2651
# Epochs: 4/20 Training loss: 0.2628
# Epochs: 4/20 Training loss: 0.2633
# Epochs: 4/20 Training loss: 0.2703
# Epochs: 4/20 Training loss: 0.2588
# Epochs: 4/20 Training loss: 0.2574
# Epochs: 4/20 Training loss: 0.2585
# Epochs: 4/20 Training loss: 0.2676
# Epochs: 4/20 Training loss: 0.2684
# Epochs: 4/20 Training loss: 0.2626
# Epochs: 4/20 Training loss: 0.2617
# Epochs: 4/20 Training loss: 0.2630
# Epochs: 4/20 Training loss: 0.2652
# Epochs: 4/20 Training loss: 0.2697
# Epochs: 4/20 Training loss: 0.2698
# Epochs: 4/20 Training loss: 0.2632
# Epochs: 4/20 Training loss: 0.2594
# Epochs: 4/20 Training loss: 0.2678
# Epochs: 4/20 Training loss: 0.2644
# Epochs: 4/20 Training loss: 0.2708
# Epochs: 4/20 Training loss: 0.2630
# Epochs: 4/20 Training loss: 0.2635
# Epochs: 4/20 Training loss: 0.2639
# Epochs: 4/20 Training loss: 0.2664
# Epochs: 4/20 Training loss: 0.2589
# Epochs: 4/20 Training loss: 0.2597
# Epochs: 4/20 Training loss: 0.2623
# Epochs: 4/20 Training loss: 0.2660
# Epochs: 4/20 Training loss: 0.2621
# Epochs: 4/20 Training loss: 0.2657
# Epochs: 4/20 Training loss: 0.2616
# Epochs: 4/20 Training loss: 0.2712
# Epochs: 4/20 Training loss: 0.2673
# Epochs: 4/20 Training loss: 0.2571
# Epochs: 4/20 Training loss: 0.2599
# Epochs: 4/20 Training loss: 0.2656
# Epochs: 4/20 Training loss: 0.2555
# Epochs: 4/20 Training loss: 0.2634
# Epochs: 4/20 Training loss: 0.2624
# Epochs: 4/20 Training loss: 0.2717
# Epochs: 4/20 Training loss: 0.2641
# Epochs: 4/20 Training loss: 0.2644
# Epochs: 4/20 Training loss: 0.2547
# Epochs: 4/20 Training loss: 0.2531
# Epochs: 4/20 Training loss: 0.2675
# Epochs: 4/20 Training loss: 0.2656
# Epochs: 4/20 Training loss: 0.2624
# Epochs: 4/20 Training loss: 0.2658
# Epochs: 4/20 Training loss: 0.2636
# Epochs: 4/20 Training loss: 0.2563
# Epochs: 4/20 Training loss: 0.2594
# Epochs: 4/20 Training loss: 0.2632
# Epochs: 4/20 Training loss: 0.2672
# Epochs: 4/20 Training loss: 0.2590
# Epochs: 4/20 Training loss: 0.2670
# Epochs: 4/20 Training loss: 0.2706
# Epochs: 4/20 Training loss: 0.2711
# Epochs: 4/20 Training loss: 0.2604
# Epochs: 4/20 Training loss: 0.2608
# Epochs: 4/20 Training loss: 0.2563
# Epochs: 4/20 Training loss: 0.2563
# Epochs: 4/20 Training loss: 0.2597
# Epochs: 4/20 Training loss: 0.2614
# Epochs: 4/20 Training loss: 0.2622
# Epochs: 4/20 Training loss: 0.2655
# Epochs: 4/20 Training loss: 0.2666
# Epochs: 4/20 Training loss: 0.2691
# Epochs: 4/20 Training loss: 0.2659
# Epochs: 4/20 Training loss: 0.2682
# Epochs: 4/20 Training loss: 0.2634
# Epochs: 4/20 Training loss: 0.2716
# Epochs: 4/20 Training loss: 0.2626
# Epochs: 4/20 Training loss: 0.2631
# Epochs: 4/20 Training loss: 0.2573
# Epochs: 4/20 Training loss: 0.2612
# Epochs: 4/20 Training loss: 0.2566
# Epochs: 4/20 Training loss: 0.2613
# Epochs: 4/20 Training loss: 0.2575
# Epochs: 4/20 Training loss: 0.2630
# Epochs: 4/20 Training loss: 0.2697
# Epochs: 4/20 Training loss: 0.2641
# Epochs: 4/20 Training loss: 0.2665
# Epochs: 4/20 Training loss: 0.2640
# Epochs: 4/20 Training loss: 0.2669
# Epochs: 4/20 Training loss: 0.2672
# Epochs: 4/20 Training loss: 0.2702
# Epochs: 4/20 Training loss: 0.2622
# Epochs: 4/20 Training loss: 0.2674
# Epochs: 4/20 Training loss: 0.2640
# Epochs: 4/20 Training loss: 0.2656
# Epochs: 4/20 Training loss: 0.2685
# Epochs: 4/20 Training loss: 0.2616
# Epochs: 4/20 Training loss: 0.2567
# Epochs: 4/20 Training loss: 0.2648
# Epochs: 4/20 Training loss: 0.2530
# Epochs: 4/20 Training loss: 0.2560
# Epochs: 4/20 Training loss: 0.2631
# Epochs: 4/20 Training loss: 0.2684
# Epochs: 4/20 Training loss: 0.2641
# Epochs: 4/20 Training loss: 0.2614
# Epochs: 4/20 Training loss: 0.2656
# Epochs: 4/20 Training loss: 0.2642
# Epochs: 4/20 Training loss: 0.2684
# Epochs: 4/20 Training loss: 0.2658
# Epochs: 4/20 Training loss: 0.2649
# Epochs: 4/20 Training loss: 0.2686
# Epochs: 4/20 Training loss: 0.2635
# Epochs: 4/20 Training loss: 0.2619
# Epochs: 4/20 Training loss: 0.2543
# Epochs: 4/20 Training loss: 0.2626
# Epochs: 4/20 Training loss: 0.2602
# Epochs: 4/20 Training loss: 0.2675
# Epochs: 4/20 Training loss: 0.2653
# Epochs: 4/20 Training loss: 0.2670
# Epochs: 4/20 Training loss: 0.2623
# Epochs: 4/20 Training loss: 0.2745
# Epochs: 4/20 Training loss: 0.2700
# Epochs: 4/20 Training loss: 0.2632
# Epochs: 4/20 Training loss: 0.2637
# Epochs: 4/20 Training loss: 0.2705
# Epochs: 4/20 Training loss: 0.2627
# Epochs: 4/20 Training loss: 0.2636
# Epochs: 4/20 Training loss: 0.2672
# Epochs: 4/20 Training loss: 0.2664
# Epochs: 4/20 Training loss: 0.2646
# Epochs: 4/20 Training loss: 0.2674
# Epochs: 4/20 Training loss: 0.2711
# Epochs: 4/20 Training loss: 0.2658
# Epochs: 4/20 Training loss: 0.2671
# Epochs: 4/20 Training loss: 0.2685
# Epochs: 4/20 Training loss: 0.2687
# Epochs: 4/20 Training loss: 0.2614
# Epochs: 4/20 Training loss: 0.2599
# Epochs: 4/20 Training loss: 0.2592
# Epochs: 4/20 Training loss: 0.2679
# Epochs: 4/20 Training loss: 0.2648
# Epochs: 4/20 Training loss: 0.2614
# Epochs: 4/20 Training loss: 0.2630
# Epochs: 4/20 Training loss: 0.2660
# Epochs: 4/20 Training loss: 0.2638
# Epochs: 4/20 Training loss: 0.2654
# Epochs: 4/20 Training loss: 0.2638
# Epochs: 4/20 Training loss: 0.2682
# Epochs: 4/20 Training loss: 0.2641
# Epochs: 4/20 Training loss: 0.2644
# Epochs: 4/20 Training loss: 0.2604
# Epochs: 4/20 Training loss: 0.2707
# Epochs: 4/20 Training loss: 0.2640
# Epochs: 4/20 Training loss: 0.2627
# Epochs: 4/20 Training loss: 0.2626
# Epochs: 4/20 Training loss: 0.2613
# Epochs: 4/20 Training loss: 0.2661
# Epochs: 4/20 Training loss: 0.2657
# Epochs: 4/20 Training loss: 0.2689
# Epochs: 4/20 Training loss: 0.2626
# Epochs: 4/20 Training loss: 0.2687
# Epochs: 4/20 Training loss: 0.2643
# Epochs: 4/20 Training loss: 0.2624
# Epochs: 4/20 Training loss: 0.2613
# Epochs: 4/20 Training loss: 0.2659
# Epochs: 4/20 Training loss: 0.2670
# Epochs: 4/20 Training loss: 0.2625
# Epochs: 4/20 Training loss: 0.2668
# Epochs: 4/20 Training loss: 0.2697
# Epochs: 4/20 Training loss: 0.2674
# Epochs: 4/20 Training loss: 0.2654
# Epochs: 4/20 Training loss: 0.2593
# Epochs: 4/20 Training loss: 0.2615
# Epochs: 4/20 Training loss: 0.2680
# Epochs: 4/20 Training loss: 0.2648
# Epochs: 4/20 Training loss: 0.2593
# Epochs: 4/20 Training loss: 0.2599
# Epochs: 4/20 Training loss: 0.2541
# Epochs: 4/20 Training loss: 0.2583
# Epochs: 4/20 Training loss: 0.2672
# Epochs: 4/20 Training loss: 0.2625
# Epochs: 4/20 Training loss: 0.2673
# Epochs: 4/20 Training loss: 0.2677
# Epochs: 4/20 Training loss: 0.2702
# Epochs: 4/20 Training loss: 0.2601
# Epochs: 4/20 Training loss: 0.2664
# Epochs: 4/20 Training loss: 0.2710
# Epochs: 4/20 Training loss: 0.2597
# Epochs: 4/20 Training loss: 0.2650
# Epochs: 4/20 Training loss: 0.2634
# Epochs: 4/20 Training loss: 0.2706
# Epochs: 4/20 Training loss: 0.2684
# Epochs: 4/20 Training loss: 0.2674
# Epochs: 4/20 Training loss: 0.2650
# Epochs: 4/20 Training loss: 0.2694
# Epochs: 4/20 Training loss: 0.2636
# Epochs: 4/20 Training loss: 0.2622
# Epochs: 4/20 Training loss: 0.2614
# Epochs: 4/20 Training loss: 0.2576
# Epochs: 4/20 Training loss: 0.2591
# Epochs: 4/20 Training loss: 0.2685
# Epochs: 4/20 Training loss: 0.2786
# Epochs: 4/20 Training loss: 0.2622
# Epochs: 4/20 Training loss: 0.2622
# Epochs: 4/20 Training loss: 0.2600
# Epochs: 4/20 Training loss: 0.2602
# Epochs: 4/20 Training loss: 0.2630
# Epochs: 4/20 Training loss: 0.2632
# Epochs: 4/20 Training loss: 0.2637
# Epochs: 4/20 Training loss: 0.2618
# Epochs: 4/20 Training loss: 0.2560
# Epochs: 4/20 Training loss: 0.2598
# Epochs: 4/20 Training loss: 0.2609
# Epochs: 4/20 Training loss: 0.2615
# Epochs: 4/20 Training loss: 0.2612
# Epochs: 4/20 Training loss: 0.2603
# Epochs: 4/20 Training loss: 0.2602
# Epochs: 4/20 Training loss: 0.2656
# Epochs: 4/20 Training loss: 0.2649
# Epochs: 4/20 Training loss: 0.2536
# Epochs: 4/20 Training loss: 0.2544
# Epochs: 4/20 Training loss: 0.2575
# Epochs: 4/20 Training loss: 0.2674
# Epochs: 4/20 Training loss: 0.2643
# Epochs: 4/20 Training loss: 0.2628
# Epochs: 4/20 Training loss: 0.2647
# Epochs: 4/20 Training loss: 0.2680
# Epochs: 4/20 Training loss: 0.2672
# Epochs: 4/20 Training loss: 0.2658
# Epochs: 4/20 Training loss: 0.2664
# Epochs: 4/20 Training loss: 0.2683
# Epochs: 4/20 Training loss: 0.2625
# Epochs: 4/20 Training loss: 0.2532
# Epochs: 4/20 Training loss: 0.2684
# Epochs: 4/20 Training loss: 0.2749
# Epochs: 5/20 Training loss: 0.2646
# Epochs: 5/20 Training loss: 0.2649
# Epochs: 5/20 Training loss: 0.2618
# Epochs: 5/20 Training loss: 0.2605
# Epochs: 5/20 Training loss: 0.2711
# Epochs: 5/20 Training loss: 0.2650
# Epochs: 5/20 Training loss: 0.2655
# Epochs: 5/20 Training loss: 0.2614
# Epochs: 5/20 Training loss: 0.2660
# Epochs: 5/20 Training loss: 0.2641
# Epochs: 5/20 Training loss: 0.2729
# Epochs: 5/20 Training loss: 0.2598
# Epochs: 5/20 Training loss: 0.2652
# Epochs: 5/20 Training loss: 0.2626
# Epochs: 5/20 Training loss: 0.2603
# Epochs: 5/20 Training loss: 0.2596
# Epochs: 5/20 Training loss: 0.2607
# Epochs: 5/20 Training loss: 0.2698
# Epochs: 5/20 Training loss: 0.2630
# Epochs: 5/20 Training loss: 0.2602
# Epochs: 5/20 Training loss: 0.2686
# Epochs: 5/20 Training loss: 0.2677
# Epochs: 5/20 Training loss: 0.2601
# Epochs: 5/20 Training loss: 0.2597
# Epochs: 5/20 Training loss: 0.2598
# Epochs: 5/20 Training loss: 0.2550
# Epochs: 5/20 Training loss: 0.2529
# Epochs: 5/20 Training loss: 0.2723
# Epochs: 5/20 Training loss: 0.2646
# Epochs: 5/20 Training loss: 0.2729
# Epochs: 5/20 Training loss: 0.2628
# Epochs: 5/20 Training loss: 0.2588
# Epochs: 5/20 Training loss: 0.2627
# Epochs: 5/20 Training loss: 0.2606
# Epochs: 5/20 Training loss: 0.2574
# Epochs: 5/20 Training loss: 0.2660
# Epochs: 5/20 Training loss: 0.2634
# Epochs: 5/20 Training loss: 0.2617
# Epochs: 5/20 Training loss: 0.2617
# Epochs: 5/20 Training loss: 0.2618
# Epochs: 5/20 Training loss: 0.2647
# Epochs: 5/20 Training loss: 0.2665
# Epochs: 5/20 Training loss: 0.2618
# Epochs: 5/20 Training loss: 0.2676
# Epochs: 5/20 Training loss: 0.2652
# Epochs: 5/20 Training loss: 0.2633
# Epochs: 5/20 Training loss: 0.2707
# Epochs: 5/20 Training loss: 0.2692
# Epochs: 5/20 Training loss: 0.2646
# Epochs: 5/20 Training loss: 0.2651
# Epochs: 5/20 Training loss: 0.2695
# Epochs: 5/20 Training loss: 0.2642
# Epochs: 5/20 Training loss: 0.2623
# Epochs: 5/20 Training loss: 0.2623
# Epochs: 5/20 Training loss: 0.2646
# Epochs: 5/20 Training loss: 0.2627
# Epochs: 5/20 Training loss: 0.2625
# Epochs: 5/20 Training loss: 0.2645
# Epochs: 5/20 Training loss: 0.2639
# Epochs: 5/20 Training loss: 0.2621
# Epochs: 5/20 Training loss: 0.2630
# Epochs: 5/20 Training loss: 0.2627
# Epochs: 5/20 Training loss: 0.2668
# Epochs: 5/20 Training loss: 0.2642
# Epochs: 5/20 Training loss: 0.2606
# Epochs: 5/20 Training loss: 0.2623
# Epochs: 5/20 Training loss: 0.2618
# Epochs: 5/20 Training loss: 0.2658
# Epochs: 5/20 Training loss: 0.2641
# Epochs: 5/20 Training loss: 0.2628
# Epochs: 5/20 Training loss: 0.2678
# Epochs: 5/20 Training loss: 0.2578
# Epochs: 5/20 Training loss: 0.2652
# Epochs: 5/20 Training loss: 0.2660
# Epochs: 5/20 Training loss: 0.2580
# Epochs: 5/20 Training loss: 0.2662
# Epochs: 5/20 Training loss: 0.2613
# Epochs: 5/20 Training loss: 0.2652
# Epochs: 5/20 Training loss: 0.2589
# Epochs: 5/20 Training loss: 0.2665
# Epochs: 5/20 Training loss: 0.2630
# Epochs: 5/20 Training loss: 0.2679
# Epochs: 5/20 Training loss: 0.2711
# Epochs: 5/20 Training loss: 0.2684
# Epochs: 5/20 Training loss: 0.2654
# Epochs: 5/20 Training loss: 0.2688
# Epochs: 5/20 Training loss: 0.2652
# Epochs: 5/20 Training loss: 0.2639
# Epochs: 5/20 Training loss: 0.2673
# Epochs: 5/20 Training loss: 0.2631
# Epochs: 5/20 Training loss: 0.2680
# Epochs: 5/20 Training loss: 0.2561
# Epochs: 5/20 Training loss: 0.2648
# Epochs: 5/20 Training loss: 0.2623
# Epochs: 5/20 Training loss: 0.2644
# Epochs: 5/20 Training loss: 0.2602
# Epochs: 5/20 Training loss: 0.2598
# Epochs: 5/20 Training loss: 0.2655
# Epochs: 5/20 Training loss: 0.2639
# Epochs: 5/20 Training loss: 0.2667
# Epochs: 5/20 Training loss: 0.2692
# Epochs: 5/20 Training loss: 0.2582
# Epochs: 5/20 Training loss: 0.2706
# Epochs: 5/20 Training loss: 0.2713
# Epochs: 5/20 Training loss: 0.2665
# Epochs: 5/20 Training loss: 0.2654
# Epochs: 5/20 Training loss: 0.2647
# Epochs: 5/20 Training loss: 0.2606
# Epochs: 5/20 Training loss: 0.2689
# Epochs: 5/20 Training loss: 0.2582
# Epochs: 5/20 Training loss: 0.2698
# Epochs: 5/20 Training loss: 0.2645
# Epochs: 5/20 Training loss: 0.2589
# Epochs: 5/20 Training loss: 0.2662
# Epochs: 5/20 Training loss: 0.2633
# Epochs: 5/20 Training loss: 0.2609
# Epochs: 5/20 Training loss: 0.2650
# Epochs: 5/20 Training loss: 0.2728
# Epochs: 5/20 Training loss: 0.2714
# Epochs: 5/20 Training loss: 0.2682
# Epochs: 5/20 Training loss: 0.2684
# Epochs: 5/20 Training loss: 0.2629
# Epochs: 5/20 Training loss: 0.2650
# Epochs: 5/20 Training loss: 0.2603
# Epochs: 5/20 Training loss: 0.2626
# Epochs: 5/20 Training loss: 0.2684
# Epochs: 5/20 Training loss: 0.2588
# Epochs: 5/20 Training loss: 0.2699
# Epochs: 5/20 Training loss: 0.2674
# Epochs: 5/20 Training loss: 0.2616
# Epochs: 5/20 Training loss: 0.2672
# Epochs: 5/20 Training loss: 0.2663
# Epochs: 5/20 Training loss: 0.2659
# Epochs: 5/20 Training loss: 0.2656
# Epochs: 5/20 Training loss: 0.2612
# Epochs: 5/20 Training loss: 0.2580
# Epochs: 5/20 Training loss: 0.2733
# Epochs: 5/20 Training loss: 0.2716
# Epochs: 5/20 Training loss: 0.2593
# Epochs: 5/20 Training loss: 0.2625
# Epochs: 5/20 Training loss: 0.2671
# Epochs: 5/20 Training loss: 0.2635
# Epochs: 5/20 Training loss: 0.2695
# Epochs: 5/20 Training loss: 0.2608
# Epochs: 5/20 Training loss: 0.2609
# Epochs: 5/20 Training loss: 0.2685
# Epochs: 5/20 Training loss: 0.2729
# Epochs: 5/20 Training loss: 0.2657
# Epochs: 5/20 Training loss: 0.2576
# Epochs: 5/20 Training loss: 0.2658
# Epochs: 5/20 Training loss: 0.2682
# Epochs: 5/20 Training loss: 0.2574
# Epochs: 5/20 Training loss: 0.2626
# Epochs: 5/20 Training loss: 0.2591
# Epochs: 5/20 Training loss: 0.2602
# Epochs: 5/20 Training loss: 0.2690
# Epochs: 5/20 Training loss: 0.2600
# Epochs: 5/20 Training loss: 0.2633
# Epochs: 5/20 Training loss: 0.2638
# Epochs: 5/20 Training loss: 0.2620
# Epochs: 5/20 Training loss: 0.2541
# Epochs: 5/20 Training loss: 0.2641
# Epochs: 5/20 Training loss: 0.2647
# Epochs: 5/20 Training loss: 0.2639
# Epochs: 5/20 Training loss: 0.2545
# Epochs: 5/20 Training loss: 0.2644
# Epochs: 5/20 Training loss: 0.2665
# Epochs: 5/20 Training loss: 0.2682
# Epochs: 5/20 Training loss: 0.2610
# Epochs: 5/20 Training loss: 0.2680
# Epochs: 5/20 Training loss: 0.2623
# Epochs: 5/20 Training loss: 0.2677
# Epochs: 5/20 Training loss: 0.2668
# Epochs: 5/20 Training loss: 0.2634
# Epochs: 5/20 Training loss: 0.2620
# Epochs: 5/20 Training loss: 0.2579
# Epochs: 5/20 Training loss: 0.2571
# Epochs: 5/20 Training loss: 0.2570
# Epochs: 5/20 Training loss: 0.2630
# Epochs: 5/20 Training loss: 0.2655
# Epochs: 5/20 Training loss: 0.2700
# Epochs: 5/20 Training loss: 0.2571
# Epochs: 5/20 Training loss: 0.2641
# Epochs: 5/20 Training loss: 0.2580
# Epochs: 5/20 Training loss: 0.2605
# Epochs: 5/20 Training loss: 0.2647
# Epochs: 5/20 Training loss: 0.2647
# Epochs: 5/20 Training loss: 0.2699
# Epochs: 5/20 Training loss: 0.2624
# Epochs: 5/20 Training loss: 0.2602
# Epochs: 5/20 Training loss: 0.2713
# Epochs: 5/20 Training loss: 0.2621
# Epochs: 5/20 Training loss: 0.2646
# Epochs: 5/20 Training loss: 0.2661
# Epochs: 5/20 Training loss: 0.2616
# Epochs: 5/20 Training loss: 0.2638
# Epochs: 5/20 Training loss: 0.2643
# Epochs: 5/20 Training loss: 0.2646
# Epochs: 5/20 Training loss: 0.2621
# Epochs: 5/20 Training loss: 0.2628
# Epochs: 5/20 Training loss: 0.2670
# Epochs: 5/20 Training loss: 0.2561
# Epochs: 5/20 Training loss: 0.2649
# Epochs: 5/20 Training loss: 0.2620
# Epochs: 5/20 Training loss: 0.2696
# Epochs: 5/20 Training loss: 0.2630
# Epochs: 5/20 Training loss: 0.2612
# Epochs: 5/20 Training loss: 0.2651
# Epochs: 5/20 Training loss: 0.2693
# Epochs: 5/20 Training loss: 0.2623
# Epochs: 5/20 Training loss: 0.2671
# Epochs: 5/20 Training loss: 0.2708
# Epochs: 5/20 Training loss: 0.2606
# Epochs: 5/20 Training loss: 0.2632
# Epochs: 5/20 Training loss: 0.2582
# Epochs: 5/20 Training loss: 0.2599
# Epochs: 5/20 Training loss: 0.2622
# Epochs: 5/20 Training loss: 0.2674
# Epochs: 5/20 Training loss: 0.2623
# Epochs: 5/20 Training loss: 0.2710
# Epochs: 5/20 Training loss: 0.2669
# Epochs: 5/20 Training loss: 0.2685
# Epochs: 5/20 Training loss: 0.2675
# Epochs: 5/20 Training loss: 0.2529
# Epochs: 5/20 Training loss: 0.2644
# Epochs: 5/20 Training loss: 0.2549
# Epochs: 5/20 Training loss: 0.2585
# Epochs: 5/20 Training loss: 0.2602
# Epochs: 5/20 Training loss: 0.2666
# Epochs: 5/20 Training loss: 0.2599
# Epochs: 5/20 Training loss: 0.2641
# Epochs: 5/20 Training loss: 0.2720
# Epochs: 5/20 Training loss: 0.2661
# Epochs: 5/20 Training loss: 0.2693
# Epochs: 5/20 Training loss: 0.2613
# Epochs: 5/20 Training loss: 0.2611
# Epochs: 5/20 Training loss: 0.2703
# Epochs: 5/20 Training loss: 0.2716
# Epochs: 5/20 Training loss: 0.2653
# Epochs: 5/20 Training loss: 0.2626
# Epochs: 5/20 Training loss: 0.2709
# Epochs: 5/20 Training loss: 0.2651
# Epochs: 5/20 Training loss: 0.2708
# Epochs: 5/20 Training loss: 0.2601
# Epochs: 5/20 Training loss: 0.2606
# Epochs: 5/20 Training loss: 0.2725
# Epochs: 5/20 Training loss: 0.2639
# Epochs: 5/20 Training loss: 0.2730
# Epochs: 5/20 Training loss: 0.2652
# Epochs: 5/20 Training loss: 0.2625
# Epochs: 5/20 Training loss: 0.2634
# Epochs: 5/20 Training loss: 0.2588
# Epochs: 5/20 Training loss: 0.2621
# Epochs: 5/20 Training loss: 0.2538
# Epochs: 5/20 Training loss: 0.2635
# Epochs: 5/20 Training loss: 0.2650
# Epochs: 5/20 Training loss: 0.2642
# Epochs: 5/20 Training loss: 0.2677
# Epochs: 5/20 Training loss: 0.2691
# Epochs: 5/20 Training loss: 0.2621
# Epochs: 5/20 Training loss: 0.2627
# Epochs: 5/20 Training loss: 0.2578
# Epochs: 5/20 Training loss: 0.2654
# Epochs: 5/20 Training loss: 0.2614
# Epochs: 5/20 Training loss: 0.2757
# Epochs: 5/20 Training loss: 0.2688
# Epochs: 5/20 Training loss: 0.2583
# Epochs: 5/20 Training loss: 0.2650
# Epochs: 5/20 Training loss: 0.2712
# Epochs: 5/20 Training loss: 0.2657
# Epochs: 5/20 Training loss: 0.2591
# Epochs: 5/20 Training loss: 0.2642
# Epochs: 5/20 Training loss: 0.2587
# Epochs: 5/20 Training loss: 0.2684
# Epochs: 5/20 Training loss: 0.2680
# Epochs: 5/20 Training loss: 0.2619
# Epochs: 5/20 Training loss: 0.2697
# Epochs: 5/20 Training loss: 0.2622
# Epochs: 5/20 Training loss: 0.2684
# Epochs: 5/20 Training loss: 0.2612
# Epochs: 5/20 Training loss: 0.2578
# Epochs: 5/20 Training loss: 0.2599
# Epochs: 5/20 Training loss: 0.2620
# Epochs: 5/20 Training loss: 0.2624
# Epochs: 5/20 Training loss: 0.2633
# Epochs: 5/20 Training loss: 0.2658
# Epochs: 5/20 Training loss: 0.2662
# Epochs: 5/20 Training loss: 0.2625
# Epochs: 5/20 Training loss: 0.2666
# Epochs: 5/20 Training loss: 0.2679
# Epochs: 5/20 Training loss: 0.2650
# Epochs: 5/20 Training loss: 0.2612
# Epochs: 5/20 Training loss: 0.2674
# Epochs: 5/20 Training loss: 0.2618
# Epochs: 5/20 Training loss: 0.2642
# Epochs: 5/20 Training loss: 0.2622
# Epochs: 5/20 Training loss: 0.2601
# Epochs: 5/20 Training loss: 0.2696
# Epochs: 5/20 Training loss: 0.2605
# Epochs: 5/20 Training loss: 0.2721
# Epochs: 6/20 Training loss: 0.2726
# Epochs: 6/20 Training loss: 0.2673
# Epochs: 6/20 Training loss: 0.2626
# Epochs: 6/20 Training loss: 0.2653
# Epochs: 6/20 Training loss: 0.2760
# Epochs: 6/20 Training loss: 0.2607
# Epochs: 6/20 Training loss: 0.2658
# Epochs: 6/20 Training loss: 0.2615
# Epochs: 6/20 Training loss: 0.2688
# Epochs: 6/20 Training loss: 0.2647
# Epochs: 6/20 Training loss: 0.2664
# Epochs: 6/20 Training loss: 0.2619
# Epochs: 6/20 Training loss: 0.2683
# Epochs: 6/20 Training loss: 0.2718
# Epochs: 6/20 Training loss: 0.2611
# Epochs: 6/20 Training loss: 0.2604
# Epochs: 6/20 Training loss: 0.2682
# Epochs: 6/20 Training loss: 0.2693
# Epochs: 6/20 Training loss: 0.2659
# Epochs: 6/20 Training loss: 0.2667
# Epochs: 6/20 Training loss: 0.2693
# Epochs: 6/20 Training loss: 0.2668
# Epochs: 6/20 Training loss: 0.2655
# Epochs: 6/20 Training loss: 0.2610
# Epochs: 6/20 Training loss: 0.2655
# Epochs: 6/20 Training loss: 0.2703
# Epochs: 6/20 Training loss: 0.2656
# Epochs: 6/20 Training loss: 0.2649
# Epochs: 6/20 Training loss: 0.2670
# Epochs: 6/20 Training loss: 0.2610
# Epochs: 6/20 Training loss: 0.2635
# Epochs: 6/20 Training loss: 0.2716
# Epochs: 6/20 Training loss: 0.2626
# Epochs: 6/20 Training loss: 0.2622
# Epochs: 6/20 Training loss: 0.2677
# Epochs: 6/20 Training loss: 0.2693
# Epochs: 6/20 Training loss: 0.2669
# Epochs: 6/20 Training loss: 0.2614
# Epochs: 6/20 Training loss: 0.2667
# Epochs: 6/20 Training loss: 0.2622
# Epochs: 6/20 Training loss: 0.2593
# Epochs: 6/20 Training loss: 0.2579
# Epochs: 6/20 Training loss: 0.2620
# Epochs: 6/20 Training loss: 0.2640
# Epochs: 6/20 Training loss: 0.2649
# Epochs: 6/20 Training loss: 0.2643
# Epochs: 6/20 Training loss: 0.2712
# Epochs: 6/20 Training loss: 0.2585
# Epochs: 6/20 Training loss: 0.2595
# Epochs: 6/20 Training loss: 0.2653
# Epochs: 6/20 Training loss: 0.2681
# Epochs: 6/20 Training loss: 0.2631
# Epochs: 6/20 Training loss: 0.2624
# Epochs: 6/20 Training loss: 0.2570
# Epochs: 6/20 Training loss: 0.2680
# Epochs: 6/20 Training loss: 0.2664
# Epochs: 6/20 Training loss: 0.2682
# Epochs: 6/20 Training loss: 0.2678
# Epochs: 6/20 Training loss: 0.2690
# Epochs: 6/20 Training loss: 0.2649
# Epochs: 6/20 Training loss: 0.2700
# Epochs: 6/20 Training loss: 0.2637
# Epochs: 6/20 Training loss: 0.2641
# Epochs: 6/20 Training loss: 0.2560
# Epochs: 6/20 Training loss: 0.2605
# Epochs: 6/20 Training loss: 0.2594
# Epochs: 6/20 Training loss: 0.2572
# Epochs: 6/20 Training loss: 0.2609
# Epochs: 6/20 Training loss: 0.2600
# Epochs: 6/20 Training loss: 0.2686
# Epochs: 6/20 Training loss: 0.2594
# Epochs: 6/20 Training loss: 0.2620
# Epochs: 6/20 Training loss: 0.2637
# Epochs: 6/20 Training loss: 0.2666
# Epochs: 6/20 Training loss: 0.2674
# Epochs: 6/20 Training loss: 0.2615
# Epochs: 6/20 Training loss: 0.2617
# Epochs: 6/20 Training loss: 0.2614
# Epochs: 6/20 Training loss: 0.2617
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-d01921e8d48d> in <module>()
#      12             targets[-1] = imgs[0]
#      13             batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: imgs,
# ---> 14                                                          targets_: targets})
#      15
#      16             print("Epochs: {}/{}".format(e+1, epochs), "Training loss: {:.4f}".format(batch_cost))
#
# /Users/congcong/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/congcong/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /Users/congcong/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/congcong/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /Users/congcong/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
